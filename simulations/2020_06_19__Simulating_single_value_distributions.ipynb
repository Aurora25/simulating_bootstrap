# %%
import numpy as np
import seaborn
seaborn.set_style("whitegrid")
seaborn.set_context("talk")

# %%
from src.population_distributions import get_population_gauss, get_population_binomial
from src.simulation import simulation, get_agg
from src.visualizations import plot_confidence_intervals_col, plot_confidende_intervals_highlight

# %% [markdown]
# ## Simulating a normal Gaussian

# %%
normal_dist = get_population_gauss(mu=0, sigma=1)
sim_res, pop_metric = simulation(normal_dist, {"mean": np.mean, "std": np.std}, num_sample_draws=100)
# Out:
# 100%|██████████| 100/100 [00:06<00:00, 14.91it/s]

# %%
get_agg(sim_res, np.sum, ["mean", "std"])
# Out:
# {'mean': 97, 'std': 93}

# %%
pop_metric
# Out:
# {'mean': 0.00013156077816565886, 'std': 1.00048824138813}

# %%
plot_confidence_intervals_col(sim_res, pop_metric, "mean")

# %%
plot_confidende_intervals_highlight(sim_res, pop_metric, "mean")

# %% [markdown]
# ## Running the simulation for Binomial Distribution

# %%
bernoulli_simulation = get_population_binomial(p=0.1, n=1)

# %%
sim_res_bin, pop_metric_bin = simulation(bernoulli_simulation, {"mean": np.mean, "std": np.std}, num_sample_draws=100)
# Out:
# 100%|██████████| 100/100 [00:07<00:00, 14.22it/s]

# %%
get_agg(sim_res_bin, np.sum, ["mean", "std"])
# Out:
# {'mean': 96, 'std': 96}

# %%
pop_metric_bin
# Out:
# {'mean': 0.10146, 'std': 0.3019368616118277}

# %%
plot_confidence_intervals_col(sim_res_bin, pop_metric_bin, metric="mean")

# %%
plot_confidende_intervals_highlight(sim_res_bin, pop_metric_bin, metric="mean")

# %% [markdown]
# ## Running simulation for extreme values

# %%
normal_dist = get_population_gauss(mu=0, sigma=1)
sim_res_extr, pop_metrics_extr = simulation(normal_dist, {"max": np.max, "min": np.min}, num_sample_draws=100, sample_size=10000, resample_size=8000)
# Out:
# 100%|██████████| 100/100 [00:16<00:00,  6.00it/s]

# %%
get_agg(sim_res_extr, np.sum, ["min", "max"])
# Out:
# {'min': 8, 'max': 14}

# %%
pop_metrics_extr
# Out:
# {'max': 4.620617274051963, 'min': -4.526985567927994}

# %%
plot_confidence_intervals_col(sim_res_extr, pop_metrics_extr, "min")

# %%
plot_confidende_intervals_highlight(sim_res_extr, pop_metrics_extr, "min")
